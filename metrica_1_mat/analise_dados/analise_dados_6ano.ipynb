# %%
import pandas as pd
import os

# %%
caminho_dados = "."
nome_arquivo = "6ano_completo.csv"

# %%
caminho_completo = os.path.join(caminho_dados, nome_arquivo)
df = pd.read_csv(caminho_completo)

print("Dados carregados com sucesso!")
# Out:
# Dados carregados com sucesso!

# %%
df
# Out:
#             nome_estudante   lista questao  \
# 0         Ana Clara Santos  lista1      Q1
# 1         Ana Clara Santos  lista1      Q2
# 2         Ana Clara Santos  lista1      Q3
# 3         Ana Clara Santos  lista1      Q4
# 4         Ana Clara Santos  lista1      Q5
# ...                    ...     ...     ...
# 2495  Benício Alves Santos  lista5      Q6
# 2496  Benício Alves Santos  lista5      Q7
# 2497  Benício Alves Santos  lista5      Q8
# 2498  Benício Alves Santos  lista5      Q9
# 2499  Benício Alves Santos  lista5     Q10
#
#                                               enunciado         classificacao  \
# 0     A biblioteca da escola recebeu novas doações d...             Incorreto
# 1     Um avião tem capacidade para 295 passageiros e...  Parcialmente Correto
# 2     Uma fábrica de brinquedos produz 138 carrinhos...  Parcialmente Correto
# 3     Uma turma de 27 alunos decidiu organizar uma v...  Parcialmente Correto
# ...

# %%
df.columns
# Out:
# Index(['nome_estudante', 'lista', 'questao', 'enunciado', 'classificacao',
#        'tipo_erro', 'subtipo_erro', 'justificativa'],
#       dtype='object')

# %%
df_lista1 = df[df['lista'] == 'lista1']

# %%
df_lista1
# Out:
#            nome_estudante   lista questao  \
# 0        Ana Clara Santos  lista1      Q1
# 1        Ana Clara Santos  lista1      Q2
# 2        Ana Clara Santos  lista1      Q3
# 3        Ana Clara Santos  lista1      Q4
# 4        Ana Clara Santos  lista1      Q5
# ..                    ...     ...     ...
# 495  Benício Alves Santos  lista1      Q6
# 496  Benício Alves Santos  lista1      Q7
# 497  Benício Alves Santos  lista1      Q8
# 498  Benício Alves Santos  lista1      Q9
# 499  Benício Alves Santos  lista1     Q10
#
#                                              enunciado         classificacao  \
# 0    A biblioteca da escola recebeu novas doações d...             Incorreto
# 1    Um avião tem capacidade para 295 passageiros e...  Parcialmente Correto
# 2    Uma fábrica de brinquedos produz 138 carrinhos...  Parcialmente Correto
# 3    Uma turma de 27 alunos decidiu organizar uma v...  Parcialmente Correto
# ...
